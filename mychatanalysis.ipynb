# %%
from pymongo import MongoClient
import re
import matplotlib.pyplot as plt
client = MongoClient('mongodb://localhost:27017/')
if(client):
   print("connected")
db = client.JOBS
collection2=db.chatbot
doc=collection2.find({})
dateslist=[]
for i in doc:
        #print(i['text'])
        msg=i['text'].split(',')
        datemsg=msg[0]
        match = re.search(r'(\d+/\d+/\d+)', datemsg)
        if match:
            dateslist.append(datemsg)
dic={}
for i in dateslist:
       dic[i]=dateslist.count(i)
dates=list(dic.keys())   
count=list(dic.values())
print(dates)
print(count)
from datetime import datetime
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as pyplot
data={'date':dates,'count':count}
df=pd.DataFrame(data,columns=['date','count'])
print(df)
# Out:
# connected
# ['30/04/19', '02/05/19', '03/05/19', '04/05/19', '05/05/19', '06/05/19', '07/05/19', '08/05/19', '09/05/19', '10/05/19', '11/05/19', '12/05/19', '13/05/19', '14/05/19', '15/05/19', '16/05/19', '17/05/19', '18/05/19', '19/05/19', '20/05/19', '21/05/19', '22/05/19', '23/05/19', '24/05/19', '25/05/19', '26/05/19', '27/05/19', '28/05/19', '29/05/19', '30/05/19', '31/05/19', '01/06/19', '02/06/19', '03/06/19']
# [319, 5, 249, 604, 382, 272, 520, 243, 387, 169, 503, 334, 195, 196, 243, 198, 404, 295, 357, 215, 599, 341, 442, 418, 4, 524, 895, 1159, 569, 314, 260, 232, 624, 517]
#         date  count
# 0   30/04/19    319
# 1   02/05/19      5
# 2   03/05/19    249
# 3   04/05/19    604
# 4   05/05/19    382
# 5   06/05/19    272
# 6   07/05/19    520
# 7   08/05/19    243
# 8   09/05/19    387
# 9   10/05/19    169
# 10  11/05/19    503
# 11  12/05/19    334
# 12  13/05/19    195
# 13  14/05/19    196
# 14  15/05/19    243
# 15  16/05/19    198
# 16  17/05/19    404
# 17  18/05/19    295
# 18  19/05/19    357
# 19  20/05/19    215
# 20  21/05/19    599
# 21  22/05/19    341
# 22  23/05/19    442
# 23  24/05/19    418
# 24  25/05/19      4
# 25  26/05/19    524
# 26  27/05/19    895
# 27  28/05/19   1159
# 28  29/05/19    569
# 29  30/05/19    314
# 30  31/05/19    260
# 31  01/06/19    232
# 32  02/06/19    624
# 33  03/06/19    517

# %%
from datetime import datetime
df['date']=[str(i).replace('0','') for i in df['date']]
print(type(df['date'][0]))
df['date']=[datetime.strptime(i, '%d/%m/%y') for i in df['date']]
#df['date']=[datetime.strptime(d, '%m/%d/%y') for d in df['date']]
print(df['date'])
# Out:
# <class 'str'>
# 0    2019-04-03
# 1    2019-05-02
# 2    2019-05-03
# 3    2019-05-04
# 4    2019-05-05
# 5    2019-05-06
# 6    2019-05-07
# 7    2019-05-08
# 8    2019-05-09
# 9    2019-05-01
# 10   2019-05-11
# 11   2019-05-12
# 12   2019-05-13
# 13   2019-05-14
# 14   2019-05-15
# 15   2019-05-16
# 16   2019-05-17
# 17   2019-05-18
# 18   2019-05-19
# 19   2019-05-02
# 20   2019-05-21
# 21   2019-05-22
# 22   2019-05-23
# 23   2019-05-24
# 24   2019-05-25
# 25   2019-05-26
# 26   2019-05-27
# 27   2019-05-28
# 28   2019-05-29
# 29   2019-05-03
# 30   2019-05-31
# 31   2019-06-01
# 32   2019-06-02
# 33   2019-06-03
# Name: date, dtype: datetime64[ns]

# %%
plt.figure(figsize=(50,20))
plt.plot(df['date'],df['count'])
plt.gcf().autofmt_xdate()
plt.show()

# %%
# Out:
# Sep 01 2018
